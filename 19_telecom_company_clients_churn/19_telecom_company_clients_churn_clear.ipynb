# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-0.0.0.1"><span class="toc-item-num">0.0.0.1&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-названий-и-типов-столбцов" data-toc-modified-id="Изменение-названий-и-типов-столбцов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изменение названий и типов столбцов</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-1.1.0.1"><span class="toc-item-num">1.1.0.1&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li></ul></li></ul></li><li><span><a href="#Объединение-датасетов" data-toc-modified-id="Объединение-датасетов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Объединение датасетов</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Работа с пропусками</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-1.4.0.1"><span class="toc-item-num">1.4.0.1&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-дополнительных-признаков" data-toc-modified-id="Создание-дополнительных-признаков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Создание дополнительных признаков</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-2.1.0.1"><span class="toc-item-num">2.1.0.1&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-характера-распределения-данных-и-мультиколлинеарности" data-toc-modified-id="Исследование-характера-распределения-данных-и-мультиколлинеарности-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Исследование характера распределения данных и мультиколлинеарности</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-Вопрос-студента💎" data-toc-modified-id="-Вопрос-студента💎-2.2.0.1"><span class="toc-item-num">2.2.0.1&nbsp;&nbsp;</span> Вопрос студента💎</a></span></li><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-2.2.0.2"><span class="toc-item-num">2.2.0.2&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-2.2.0.3"><span class="toc-item-num">2.2.0.3&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Обучение-и-анализ-работы-моделей" data-toc-modified-id="Обучение-и-анализ-работы-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение и анализ работы моделей</a></span></li><li><span><a href="#Оценка-результатов" data-toc-modified-id="Оценка-результатов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Оценка результатов</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-Комментарий-студента💎" data-toc-modified-id="-Комментарий-студента💎-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span> Комментарий студента💎</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Проект "Отток клиентов компании ТелеДом"

# %% [markdown]
# Оператор связи «ТелеДом» хочет бороться с оттоком клиентов. Для этого его сотрудники начнут предлагать промокоды и специальные условия всем, кто планирует отказаться от услуг связи. Чтобы заранее находить таких пользователей, «ТелеДому» нужна модель, которая будет предсказывать, разорвёт ли абонент договор.
#
# Команда оператора предоставила нам персональные данные о некоторых клиентах, информацию об их тарифах и услугах. Основная задача проекта — обучить на этих данных модель для прогноза оттока клиентов.
# Исходные данные состоят из четырех датасетов:
# 1. *contract_new.csv*. Датасет, содержащий информацию о заключенных контрактах с клиентом, датах начала и окончания, а также о деталях частоты и количества платежей.
# 2. *personal_new.csv*. Датасет содержит персональную информацию о каждом клиенте - его социальный статус, наличие супругов и иждевенцев,
# 3. *internet_new.csv*. Датасет включает информацию о факте использования услуг интернета, типе подключения, а также статус подключения дополнительных интернет-услуг.
# 4. *phone_new.csv*. Датасет содержит строки только для тех клиентов, которые используют услуги телефонии, а также содержит маркер подключения к нескольким линиям одновременно.
#
# Требования к скорости работы модели, затратам памяти и промежуточным метрикам precision и recall со стороны заказчика отсутствуют.
#
# Этапы проекта:
# 1. Предобработка данных.
#     - Ознакомиться с имеющимися данными.
#     - Изменить название и тип столбцов где необходимо.
#     - Объединить все данные в один датасет.
#     - Проверить наличие явных и неявных дубликатов.
#     - Удалить или заполнить пропуски.
# 2. Исследовательский анализ данных и подготовка к обучению.
#     - Выделить целевой признак.
#     - Создать дополнительные признаки, имеющие значение для обучения моделей.
#     - Исследовать характер распределения данных.
#     - Исследовать данные на предмет аномалий и выбросов. Обработать их, где необходимо.
#     - Исследовать признаки на мультиколлинеарность и утечку целевого признака.
#     - Удалить данные, не имеющие практической пользы для построения модели.
#     - Подготовить данные для построения моделей (масштабирование, кодирование, если применимо).
# 3. Обучение и анализ работы моделей:
#     - Построить и обучить несколько моделей (минимум две).
#     - Построение различных типов моделей и подбор гиперпараметров.
#     - Оценка метрик моделей. Выбор лучшей. Оценка качества моделей будет произвдиться с помощью метрики ROC AUC.
#     - Проверка выбранной модели на тестовой выборки.
# 4. Оценка результатов.
#     - Оценка важности влияния признаков на целевой показатель.
#     - Оценка качества работы модели и матрицы ошибок.
#     - Построение графиков ROC AUC.
# 5. Общий вывод.
#
# Цель проекта - построить модель, имеющую максимальный показатель метрики ROC AUC на тестовой выборке.
# Метрика должна иметь минимальное значение не менее 0.85, а целевой показатель для хорошей модели - не менее 0.88.
# Данная модель должна помочь компании ТелеДом в выделении клиентов, собирающихся прекратить использование услуг компании с целью выделения им дополнительной мотивации и их возможного удержания.
# Также необходимо предложить заказчику возможные рекомендации по улучшению модели в зависимости от текущих целей и возможностей бизнеса.

# %% [markdown]
# ## Предобработка данных

# %%
pip install sweetviz

# %%
pip install pydantic-settings

# %%
pip install lightgbm

# %%
pip install catboost

# %%
pip install scikit-learn

# %%
pip install shap

# %%
# импортируем библиотеки

import pandas as pd
import numpy as np
import seaborn as sns
import os
import phik
import sklearn

from scipy import stats as st
from matplotlib import pyplot as plt
from sklearn.compose import make_column_transformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import (accuracy_score, 
                             f1_score, 
                             roc_curve,
                             roc_auc_score,
                             make_scorer, 
                             confusion_matrix, 
                             recall_score, 
                             precision_score)
from sklearn.utils import shuffle
from tqdm.notebook import tqdm
from phik.report import plot_correlation_matrix
from phik import report


import sweetviz as sv 
import shap
from lightgbm import LGBMClassifier
from catboost import Pool, CatBoostClassifier

# %%
# глобальные константы

RANDOM_STATE = 150324
DATASET_DOWNLOAD_DATE = '2020-02-01'

# %%
pd.set_option('display.max_columns', None)

# %%
def load(file_name):
    
    pth1 = 'C:/Users/user/Yandex Projects/' + file_name
    pth2 = '/datasets/' + file_name
    
    if os.path.exists(pth1):
        query = pd.read_csv(pth1)
    elif os.path.exists(pth2):
        query = pd.read_csv(pth2)
    else:
        print('No path found')
        
    return query

# %%
data_contract = load('contract_new.csv')
data_contract.info()
data_contract.head()

# %%
data_personal = load('personal_new.csv')
data_personal.info()
data_personal.head()

# %%
data_internet = load('internet_new.csv')
data_internet.info()
data_internet.head()

# %%
data_phone = load('phone_new.csv')
data_phone.info()
data_phone.head()

# %% [markdown]
# Итак мы получили 4 датасета с различной информацией - о контрактах с клиентами, их персональных данных, наличии услуг интернета и телефонии.
#
# Во всех датасетах и их столбцах отсутствуют пропуски.
# В первых двух датасетах имеется 7043 строки, в 3 и 4 - по 5517 и 6361 соответственно, что характеризует наличие или отсутствие соответствующей услуги.
#
# Так как для всех таблиц первичным ключом является customer ID, и объединять мы будем именно по нему, сразу проверим их уникальность, а также то, что в меньших таблицах не содержатся ID, которых нет в основном датасете data_contract.

# %%
data_list = [data_contract, data_personal, data_internet, data_phone]

# %%
for i in data_list:
    print(i.shape[0])
    print(i['customerID'].nunique())
    print()

# %%
# также проверим, что в датасетах 2, 3 и 4 нет других уникальных ID, кроме тех, которые содержатся в data_contract
for i in range(1, 4):
    print(data_contract.shape[0] - data_list[i].shape[0])
    print(len(set(data_contract['customerID']) - set(data_list[i]['customerID'])))
    print()

# %% [markdown]
# ### Изменение названий и типов столбцов

# %% [markdown]
# Приведём названия столбцов к snake_case и изменим их типы, чтобы они соответствовали хранящимся в них данных.

# %%
data_contract = data_contract.rename(columns={
    'customerID': 'customer_id',
    'BeginDate': 'service_start_date',
    'EndDate': 'service_end_date',
    'Type': 'payment_type',
    'PaperlessBilling': 'is_paperless_billing',
    'PaymentMethod': 'payment_method',
    'MonthlyCharges': 'monthly_costs',
    'TotalCharges': 'total_costs'
})
data_contract.columns

# %%
data_contract['service_start_date'] = pd.to_datetime(data_contract['service_start_date'])

# %%
# так как в столбце service_end_date помимо дат есть No, 
# заменим все No на выделяющуюся дату 2000-01-01
data_contract.loc[data_contract['service_end_date'] == 'No', 'service_end_date'] = DATASET_DOWNLOAD_DATE

# %%
data_contract['service_end_date'] = pd.to_datetime(data_contract['service_end_date'])

# %%
# видим, что столбец total_costs имеет тип object
# скорее всего это происходит потому, что есть строки, в которых стоит значение ' '

data_contract[data_contract['total_costs'] == ' '].count()

# %%
# так как таких строк немного, можем убрать их из датасета

data_contract = data_contract[data_contract['total_costs'] != ' ']

# %%
data_contract['total_costs'] = data_contract['total_costs'].astype('float')

# %%
data_personal = data_personal.rename(columns={
    'customerID': 'customer_id',
    'SeniorCitizen': 'is_senior_citizen',
    'Partner': 'has_spouse',
    'Dependents': 'has_dependents'
})
data_personal.columns

# %%
data_internet = data_internet.rename(columns={
    'customerID': 'customer_id',
    'InternetService': 'internet_connection_type',
    'OnlineSecurity': 'online_security',
    'OnlineBackup': 'cloud_file_storage',
    'DeviceProtection': 'antivirus',
    'TechSupport': 'tech_premium_support',
    'StreamingTV': 'streaming_tv',
    'StreamingMovies': 'streaming_movies'
})
data_internet.columns

# %%
data_phone = data_phone.rename(columns={
    'customerID': 'customer_id',
    'MultipleLines': 'has_multiple_lines'
})
data_phone.columns

# %% [markdown]
# ### Объединение датасетов

# %% [markdown]
# Теперь присоединим все датасеты по ключу - customer_id - к основной таблице data_contract с помощью "левого" присоединения.

# %%
data_list = [data_contract, data_personal, data_internet, data_phone]

# %%
# для начала поместим customer_id в индексы всех таблиц
# как признак он нам точно не понадобится ввиду уникальности своих значений
for i in data_list:
    i.set_index('customer_id', inplace=True)
    display(i.head(1))

# %%
data = data_contract.join(data_personal)
data = data.join(data_internet)
data = data.join(data_phone)

data.info()
data.head()

# %% [markdown]
# ### Проверка на дубликаты

# %% [markdown]
# Проверим на явные и неявные дубликаты. Но для начала приведём все значения в столбцах с типом object к нижнему регистру.

# %%
object_columns = ['payment_type',
                  'is_paperless_billing',
                  'payment_method',
                  'gender',
                  'has_spouse',
                  'has_dependents', 
                  'internet_connection_type', 
                  'online_security', 
                  'cloud_file_storage', 
                  'antivirus',
                  'tech_premium_support',
                  'streaming_tv',
                  'streaming_movies',
                  'has_multiple_lines']
for i in object_columns:
    data[i] = data[i].str.lower()

# %%
data.head()

# %%
data.duplicated().sum()

# %%
# количество явных дубликатов невелико, можем смело их удалить
data = data.drop_duplicates()

# %%
# теперь попробуем найти строки, похожие на неявные дубликаты
data[['service_start_date',
      'service_end_date',
      'payment_type', 
      'payment_method', 
      'total_costs',
      'gender']].duplicated().sum()

# %%
data.drop_duplicates(subset=[
      'service_start_date',
      'service_end_date',
      'payment_type', 
      'payment_method', 
      'total_costs',
      'gender'
], inplace=True)

# %% [markdown]
# ### Работа с пропусками

# %% [markdown]
# В объединенном датасете пропуски можно разделить на два типа - те, которые перекочевали из data_internet и те, что пришли из data_phone.
#
# В обоих случаях пропуск означает то, что клиент не пользовался услугами интернет и/или телефона соответственно, поэтому пропуски можно заменить на категории 'internet not used' и 'phone not used'.

# %%
data[['internet_connection_type', 
      'online_security', 
      'cloud_file_storage', 
      'antivirus', 
      'tech_premium_support', 
      'streaming_tv', 
      'streaming_movies']] = data[['internet_connection_type', 
                                   'online_security', 
                                   'cloud_file_storage', 
                                   'antivirus', 
                                   'tech_premium_support', 
                                   'streaming_tv', 
                                   'streaming_movies']].fillna('internet not used')

# %%
data['has_multiple_lines'] = data['has_multiple_lines'].fillna('phone not used')

# %%
data.info()

# %% [markdown]
# Итак в течение первого этапа проекта мы выполнили следующие действия:
# - Ознакомились с имеющимися данными. Загрузили 4 датасета и изучили их структуру.
# - Изменили название и привели их к snake_case
# - Изменили тип столбцов, где это необходимо:
#     - service_start_date и service_end_date на тип datetime (предварительно заменим No на выделяющуюся дату).
#     - total costs на float, удалив строки, где значение было равно ' '.
# - Объединили все данные в один датасет по первичному ключу customer_id.
# - Проверили наличие явных и неявных дубликатов и, ввиду их незначительности, удалили их.
# - Для столбцов из датасетов data_internet и data_phone заполнили пропуски на отдельные категории 'internet not used' и 'phone not used' соответственно.
#
# Данные подготовлены для дальнейшего анализа.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# В данном разделе нам необходимо выполнить следующие ключевые моменты:
# - Выделить целевой признак.
# - Создать дополнительные признаки, имеющие значение для обучения моделей.
# - Исследовать характер распределения данных.
# - Исследовать данные на предмет аномалий и выбросов. Обработать их, где необходимо.
# - Исследовать признаки на мультиколлинеарность и утечку целевого признака.
# - Удалить данные, не имеющие практической пользы для построения модели.
# - Подготовить данные для построения моделей (масштабирование, кодирование, если применимо).

# %%
# выделяем целевой признак
data.loc[data['service_end_date'] == DATASET_DOWNLOAD_DATE, 'client_churn'] = 0
data['client_churn'] = data['client_churn'].fillna(1)
data['client_churn'] = data['client_churn'].astype('int')

# %% [markdown]
# ### Создание дополнительных признаков

# %% [markdown]
# В качестве дополнительных признаков в данной работе предлагается создать:
# - Длительность взаимодействия клиента и компании (на момент среза).
# - Подключен ли у клиента интернет.
# - Подключен ли у клиента телефон.
# - Пользуется ли клиент любыми дополнительными услугами.

# %%
data['service_duration'] = data['service_end_date'] - data['service_start_date']

# %%
data['service_duration'] = data['service_duration'].dt.days

# %%
# далее создадим признак того, подключен ли у клиента интернет
data.loc[data['internet_connection_type'] == 'internet not used', 'uses_internet'] = 0
data['uses_internet'] = data['uses_internet'].fillna(1)
data['uses_internet'] = data['uses_internet'].astype('int')

# %%
data['internet_connection_type'].unique()

# %%
# следующий признак - подключен ли у клиента телефон
data.loc[data['has_multiple_lines'] == 'phone not used', 'uses_phone'] = 0
data['uses_phone'] = data['uses_phone'].fillna(1)
data['uses_phone'] = data['uses_phone'].astype('int')

# %%
# также отдельный признак будет означать, подключал ли клиент какие-либо дополнительные услуги
data['has_add_services'] = (data[['online_security',
                                  'cloud_file_storage',
                                  'antivirus', 
                                  'tech_premium_support',
                                  'streaming_tv',
                                  'streaming_movies',
                                  'has_multiple_lines']] != 'no').any(axis='columns').astype('int')

# %% [markdown]
# ### Исследование характера распределения данных и мультиколлинеарности

# %%
# исследуем данные с помощью sweetviz
sv_report = sv.analyze(data)

# %%
sv_report.show_html('data_analysis.html')

# %% [markdown]
# Большая часть данных распределена адекватно.
# Значимых выбросов и/или аномалий не выявлено.

# %%
# проведем анализ с помощью библиотеки phik для выявления и анализа мультиколлинеарности
# выделяем столбцы с интервальными признаками
interval_cols = ['monthly_costs', 'total_costs', 'service_duration']

phik_overview = data.phik_matrix(interval_cols=interval_cols)
phik_overview = phik_overview.round(2)

# %%
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map="Reds",
                        title=r"correlation $\phi_K$",
                        fontsize_factor=0.9,
                        figsize=(10, 8))
plt.tight_layout()

# %% [markdown]
# Проанализировав матрицу корреляций, можно сделать следующие выводы.
# - Целевой столбец client_churm имеет сильную корреляцию с service_end_date (что логично), а значит последний должен быть удалён во избежание утечки данных.
# - Созданный столбец uses_phone имеет значимую корреляцию (1.0) со столбцом has_multiple_lines, но последний имеет более сильную взаимосвязь с целевым столбцов, поэтому из них двоих оставим только has_multiple_lines.
# - Столбец uses_internet имеет значимую корреляцию со всеми столбцами соответствующих дополнительных интернет-услуг, которые также значимо коррелируют между собой, поэтому из всей группы этих признаков оставим только uses_internet.
# - Столбцы service_duration и столбец service_start_date также имеют логичную значимую корреляцию между собой, удаляем один из них.
# - Столбец has_dependents имеет очень слабую корреляцию со всем другими столбцами за исключением has_spouse, поэтому смело можем его удалять.
# - Столбец gender не имеет никакой значимой корреляции ни с одним столбцом, включая целевой.
#
# Итого, удаляем мы следующие столбцы:
# - service_end_date
# - uses_phone
# - streaming_movies
# - streaming_tv
# - tech_premium_support
# - antivirus
# - cloud_file_storage
# - online_security
# - internet_connection_type
# - service_start_date
# - has_dependents
# - gender

# %%
data_dropped = data.drop(['service_end_date',
                        'uses_phone',
                        'streaming_movies',
                        'streaming_tv',
                        'tech_premium_support',
                        'antivirus',
                        'cloud_file_storage',
                        'online_security',
                        'internet_connection_type',
                        'service_start_date',
                        'has_dependents',
                        'gender'], axis=1)

# %%
data_dropped.info()

# %%
data_dropped.head()

# %%
# проанализируем баланс классов в нашем итоговом датасете
data_dropped['client_churn'].mean()

# %% [markdown]
# Видим, что положительный целевой класс составляет порядка 15% от всего датасета.
# Учтём это при разбиении на обучающую и тестовую выборки, а также при обучении моделей с помощью встроенных средств балансировки.

# %%
features = data_dropped.drop('client_churn', axis=1)
target = data_dropped['client_churn']

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=RANDOM_STATE, stratify=target)

print(features_train.shape[0])
print(features_test.shape[0])
print(target_train.shape[0])
print(target_test.shape[0])

# %%
# проверим баланс целевого признака в получившихся выборках
display(target_train.mean())
target_test.mean()

# %% [markdown]
# Теперь подготовим категориальные и количественные признаки - проведём кодирование OHE и OD, а также масштабируем их для использования в модели логистической регрессии.

# %%
# проведём Ordinal encoding для модели случайного леса

features_train_ord_encoded = features_train.copy()
features_test_ord_encoded = features_test.copy()

object_features_list = features_train.select_dtypes(include='object').columns.to_list()
print(object_features_list)

# %%
num_features_list = features_train.select_dtypes(exclude='object').columns.to_list()
num_features_list.remove('is_senior_citizen')
num_features_list.remove('uses_internet')
num_features_list.remove('has_add_services')
num_features_list

# %%
# создадим column_transformer для преобразования данных 
# для модели случайного леса подойдет Ordinal encoder

features_train_oe = features_train.copy()
features_test_oe = features_test.copy()

# %%
col_transformer_oe = make_column_transformer(
    (
        OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1),
        object_features_list
    ),
    remainder='passthrough',
    verbose_feature_names_out=False
)

# %%
# для модели логистической регрессии - OHE и масштабирование

features_train_ohe_scaled = features_train.copy()
features_test_ohe_scaled = features_test.copy()

# %%
col_transformer_ohe_scaler = make_column_transformer(
    (
        OneHotEncoder(drop='first', handle_unknown='ignore'),
        object_features_list
    ),
    (
        StandardScaler(),
        num_features_list
    ),
    remainder='passthrough',
    verbose_feature_names_out=False
)

# %% [markdown]
# Итого в течение второго этапа работы мы выполнили следующие действия:
# - Выделили в отдельный столбец целевой признак.
# - Создали дополнительные признаки, включая:
#     - Длительность взаимодействия клиента и компании (на момент среза).
#     - Подключен ли у клиента интернет.
#     - Подключен ли у клиента телефон.
#     - Пользуется ли клиент любыми дополнительными услугами.
# - Исследовали характер распределения данных. По результатам исследования значимых выбросов и/или аномалий не обнаружено.
# - Исследовали признаки на мультиколлинеарность и утечку целевого признака с помощью библиотеки phik. Итого в связи с мультиколлинеарность или с утечкой целевого признака были убраны следующие столбцы:
#     - service_end_date
#     - uses_phone
#     - streaming_movies
#     - streaming_tv
#     - tech_premium_support
#     - antivirus
#     - cloud_file_storage
#     - online_security
#     - internet_connection_type
#     - service_duration
#     - has_dependents
#     - gender
# - Разделили датасет на features и target.
# - Разбили данные на обучающую и тестовую выборки в соотношении 3:1.
# - Подготовили данные для построения моделей (провели OHE кодирование и масштабирование для модели логистической регрессии, а также Ordinal кодирование для модели случайного леса).
#
# Данные подготовлены для построения и обучения моделей.

# %% [markdown]
# ## Обучение и анализ работы моделей

# %% [markdown]
# В течение данного этапа нам необходимо:
# - Построить и обучить несколько моделей (минимум две), а также подобрать для них гиперпараметры. Для построения были выбраны следующие:
#     - Случайный лес.
#     - Логистическая регрессия.
#     - LGBM.
#     - CatBoost.
# - Оценка метрик моделей. Выбор лучшей. Оценка качества моделей будет произвдиться с помощью метрики ROC AUC.
# - Проверка выбранной модели на тестовой выборке. Метрика ROC AUC должна быть не менее 0.85.
#
# Наличие дисбаланса классов в нашем датасете будем невелировать с помощью гиперпараметров моделей.

# %%
# начнем с модели случайного леса

random_forest = RandomForestClassifier(random_state=RANDOM_STATE)

pipline_forest = make_pipeline(col_transformer_oe, random_forest)

forest_parameters_grid = {
    
    # учитываем дисбаланс классов в нашем датасете и проверим качество работы модели при балансировке классов и без неё
    'randomforestclassifier__class_weight' : ['balanced', None],
    'randomforestclassifier__max_depth' : range(2, 7),
    'randomforestclassifier__n_estimators' : list(map(int, np.linspace(60, 160, 6)))
}

forest_grid_cv = GridSearchCV(
    pipline_forest,
    forest_parameters_grid,
    cv=5,
    scoring = 'roc_auc',
    verbose=3,
    n_jobs=-1
)
forest_grid_cv.fit(features_train_oe, target_train)

forest_best_score = round(forest_grid_cv.best_score_, 2)

print(f'Наилучшее значение параметра max_depth: {forest_grid_cv.best_params_}') 
print(f'Наилучший показатель ROC AUC: {forest_best_score}')

# %% [markdown]
# Мы получили, что наибольшее значение ROC AUC достигается при следующих значениях гиперпараметров:
# - max_depth = 6
# - n_estimators = 100
# - ROC AUC = 0.82

# %%
# начнем с модели случайного леса

logistic_regression = LogisticRegression(random_state=RANDOM_STATE)

pipline_log_reg = make_pipeline(col_transformer_ohe_scaler, logistic_regression)


regression_parameters_grid = {
    'logisticregression__class_weight' : ['balanced', None],
    'logisticregression__penalty' : ['l1', 'l2'],
    'logisticregression__C' : [0.5, 1.0, 3.0, 5.0, 7.0, 10.0],
    'logisticregression__solver' : ['liblinear']
}

regression_grid_cv = GridSearchCV(
    pipline_log_reg,
    regression_parameters_grid,
    cv=5,
    scoring = 'roc_auc',
    verbose=3,
    n_jobs=-1
)
regression_grid_cv.fit(features_train_ohe_scaled, target_train)

log_regression_best_score = round(regression_grid_cv.best_score_, 2)

print(f'Наилучшее значение параметра max_depth: {regression_grid_cv.best_params_}') 
print(f'Наилучший показатель ROC AUC: {log_regression_best_score}')

# %% [markdown]
# Для логистической регрессии:
# - С = 7
# - class_weight = 'balanced'
# - solver = 'liblinear'
# - ROC AUC = 0.76

# %%
# Теперь переходим к градиентному бустингу с помощью LGBM

lgbm_model = LGBMClassifier(random_state=RANDOM_STATE)

pipline_lgbm = make_pipeline(col_transformer_oe, lgbm_model)

lgbm_parameters_grid = {
    'lgbmclassifier__class_weight' : ['balanced', None],
    'lgbmclassifier__max_depth' : range(2, 6),
    'lgbmclassifier__n_estimators' : list(map(int, np.linspace(1300, 1700, 5))),
    'lgbmclassifier__learning_rate': [0.1]
}

lgbm_grid_cv = GridSearchCV(
    pipline_lgbm,
    lgbm_parameters_grid,
    cv=5,
    scoring = 'roc_auc',
    verbose=1,
    n_jobs=-1
)
lgbm_grid_cv.fit(features_train_oe, target_train)

lgbm_best_score = round(lgbm_grid_cv.best_score_, 2)

print(f'Наилучшие значения параметров: {lgbm_grid_cv.best_params_}') 
print(f'Наилучший показатель ROC AUC: {lgbm_best_score}')

# %% [markdown]
# Для LGBM:
# - learning_rate': 0.1
# - max_depth': 2
# - n_estimators': 1600
# - ROC AUC = 0.90

# %%
# перейдем к последней модели - CatBoost
catboost_model = CatBoostClassifier(random_state=RANDOM_STATE, verbose=False)

pipline_catboost = make_pipeline(col_transformer_oe, catboost_model)

catboost_parameters_grid = {
    'catboostclassifier__max_depth' : range(2,6),
    'catboostclassifier__n_estimators' : list(map(int, np.linspace(1800, 2300, 6))),
    'catboostclassifier__learning_rate': [0.1]
}

catboost_grid_cv = GridSearchCV(
    pipline_catboost,
    catboost_parameters_grid,
    cv=5,
    scoring = 'roc_auc',
    verbose=1,
    n_jobs=-1
)
catboost_grid_cv.fit(features_train_oe, target_train)

catboost_best_score = round(catboost_grid_cv.best_score_, 2)

print(f'Наилучшие значения параметров: {catboost_grid_cv.best_params_}') 
print(f'Наилучший показатель ROC AUC: {catboost_best_score}')

# %% [markdown]
# Для CatBoost:
# - learning_rate': 0.1
# - max_depth': 2
# - n_estimators': 2300
# - ROC AUC = 0.93

# %%
roc_auc_table = pd.DataFrame({
    'roc_auc_score': [forest_best_score, log_regression_best_score, lgbm_best_score, catboost_best_score]},
    index=['Random Forest', 'Logistic Regression', 'LGBM', 'CatBoost']
)
roc_auc_table

# %% [markdown]
# По итогам обучения и валидации моделей наилучший показатель ROC AUC продемонстрировала модель CatBoost.
#
# Именно её мы будем использовать для проверки на тестовой выборке.

# %%
catboost_model_test = CatBoostClassifier(max_depth=2, n_estimators=2300,
    learning_rate=0.1, random_state=RANDOM_STATE, verbose=False)

features_train_oe_final = pd.DataFrame(
    col_transformer_oe.fit_transform(features_train_oe),
    columns=col_transformer_oe.get_feature_names_out()
)

features_test_oe_final = pd.DataFrame(
    col_transformer_oe.transform(features_test_oe),
    columns=col_transformer_oe.get_feature_names_out()
)


catboost_model_test.fit(features_train_oe_final, target_train)

preds = catboost_model_test.predict(features_test_oe_final)

probabilities_test = catboost_model_test.predict_proba(features_test_oe_final)
probabilities_one_test = probabilities_test[:, 1]

best_roc_auc = roc_auc_score(target_test, probabilities_one_test)
print(f'Значение метрики ROC AUC на тестовой выборке для лучшей модели: {best_roc_auc}')

# %% [markdown]
# Итак, в течение третьего этапа проекта мы выполнили следующие действия:
# - Построили, обучили и подобрали гиперпараметры для четырех моделей:
#     - Случайный лес.
#     - Логистическая регрессия.
#     - LGBM.
#     - CatBoost.
# - Оценка метрик моделей производилась по ROC AUC.
# - Лучшей моделью оказалась модель CatBoost.
# - Была проведена проверка выбранной модели на тестовой выборке. Метрика ROC AUC составила 0.943, что укладывается в целевой показатель проекта.

# %% [markdown]
# ## Оценка результатов

# %% [markdown]
# В течение данного этапа нам предстоит выполнить следующие действия:
# - Построение графиков ROC AUC.
# - Оценка качества работы модели и матрицы ошибок.
# - Оценка важности влияния признаков на целевой показатель.
# - Рекомендации заказчику.

# %%
# начнем с построения графика ROC AUC для лучшей модели

sns.set_theme(style='darkgrid')

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)

plt.figure(figsize=(8,6))

plt.plot(fpr, tpr, linewidth=3)

plt.plot([0, 1], [0, 1],  linewidth=3, linestyle='--')

plt.xlim(0,1)
plt.ylim(0,1)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('ROC-кривая')
plt.show()

# %%
# оценим матрицу ошибок модели, а также метрики precision и recall

print(confusion_matrix(target_test, preds))
print()
print(f'Метрика Precision: {precision_score(target_test, preds)}')
print(f'Метрика Recall: {recall_score(target_test, preds)}')

# %% [markdown]
# Глядя на матрицу ошибок и метрики precision и recall можно заключить, что на текущий момент модель имеет высокую метрику Precision, а метрика Recall существенно ниже.
# Это говорит о том, что сейчас у модели довольно мало ложных срабатываний - если модель сообщила о том, что клиент собирается покинуть компанию, это действительно так с вероятностью 94%.
#
# С другой стороны, невысокий показатель Recall говорит о том, что охват всех положительных целевых показателей невелик - модели удалось отыскать около 64% всех клиентов, собравшихся отказаться от услуг компании ТелеДом.
#
# Дальнейшее решение о доработке модели необходимо принимать на основании возможностей бизнеса:
# - Если позволяет финансовое состояние компании, стоит увеличить метрику Recall - в таком случае процент ложноположительных прогнозов увеличится, что повлечет дополнительные затраты на промокоды тем клиентам, которые не являются целевыми, но взамен большинство клиентов, планирующих отказаться от услуг, точно получат свой промокод.
# - Если компания ограничена в средствах, то можно оставить модель в её текущем состоянии, либо еще увеличить метрику Precision. В таком случае промокоды получат действительно только те клиенты, которые задумывались об уходи из компании.

# %%
# теперь перейдем к оценке влияния признаков на итоговый результат

explainer = shap.Explainer(catboost_model_test.predict, features_test_oe_final)

shap_values = explainer(features_test_oe_final)

# %%
features_test_oe_final

# %%
features_test

# %%
shap.summary_plot(shap_values, plot_type='violin')

# %% [markdown]
# Проанализировав график важности признаков, мы можем сделать следующие выводы:
# - Наибольший вклад в целевой показатель вносит признак длительности взаимодействия клиента и компании:
#     - Чем короче срок этого взаимодействия, тем чаще клиенты отказываются от услуг компании.
#     - Клиенты, имеющие средний срок и длительный работы с компанией наименее склонны к уходу.
# - Второй по значимости признак - общие затраты на услуги:
#     - Клиенты, имеющие общие затраты выше среднего показателя наиболее склонны к уходу. Верно и обратное.
# - Третий по значимости признак - тип оплаты (payment_type):
#     - Клиенты, тип оплаты которых раз в два года более склонны к уходу чем те, которые оплачивают раз в год. А последние в свою очередь более склонны к уходу чем клиенты, оплачивающие услуги раз в месяц. Возможно, здесь имеет влияние большой разовый платеж, который приходится делать клиентам с двугодичным периодом оплаты.
# - Четвертый признак - величина ежемесячных трат (monthly_costs). Здесь имеется полная аналогия с признаком total_costs - чем выше ежемесячные затраты, тем больше вероятность ухода клиента.
# - Последний более менее значимый признак - наличие супруга клиента:
#     - Клиенты, имеющие супругов, более склонны к уходу чем те, у которых их нет.

# %% [markdown]
# В качестве рекомендаций заказчику в данном случае можно посоветовать максимально направить усилия на улучшение пользовательского опыта в начале взаимодействия с компанией, так как именно новые пользователи - наиболее уязвимая часть аудитории.
#
# По возможности необходимо предоставлять новым пользователям скидки и промокоды на пользование различными услугами, так как стоимость услуг - второй наиболее важный фактор принятия решения об уходе из компании.
#
# В качестве третьей меры можно предложить убрать из тарифного плана опции оплаты услуг раз в два года в пользу более коротких сроков, например, раз в полгода, так как, судя по результатам моделирования, именно пользователи с таким типом подписки имеют наибольший шанс уйти из компании. Возможно, здесь имеет влияние большой разовый платеж, который приходится делать клиентам с двугодичным периодом оплаты.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В данном проекте была проведена работа по анализу и моделированию портрета клиента, который собирается перестать пользоваться услугами компании "ТелеДом" с целью уменьшения оттока клиентов.
#
# Работа состояла из следующих этапов:
# 1. Предобработка данных.
# 2. Исследовательский анализ данных и подготовка к обучению.
# 3. Обучение и анализ работы моделей.
# 4. Оценка результатов.
# 5. Общий вывод.
#
# В течение данных этапов были выполнены следующие действия.
#
# **1. Предобработка данных**
# - Ознакомились с имеющимися данными. Загрузили 4 датасета и изучили их структуру.
# - Изменили название и привели их к snake_case
# - Изменили тип столбцов, где это необходимо:
#     - service_start_date и service_end_date на тип datetime (предварительно заменим No на выделяющуюся дату).
#     - total costs на float, удалив строки, где значение было равно ' '.
# - Объединили все данные в один датасет по первичному ключу customer_id.
# - Проверили наличие явных и неявных дубликатов и, ввиду их незначительности, удалили их.
# - Для столбцов из датасетов data_internet и data_phone заполнили пропуски на отдельные категории 'internet not used' и 'phone not used' соответственно.
#
# **2. Исследовательский анализ данных и подготовка к обучению**
# - Выделили в отдельный столбец целевой признак.
# - Создали дополнительные признаки, включая:
#     - Длительность взаимодействия клиента и компании (на момент среза).
#     - Подключен ли у клиента интернет.
#     - Подключен ли у клиента телефон.
#     - Пользуется ли клиент любыми дополнительными услугами.
# - Исследовали характер распределения данных. По результатам исследования значимых выбросов и/или аномалий не обнаружено.
# - Исследовали признаки на мультиколлинеарность и утечку целевого признака с помощью библиотеки phik. Итого в связи с мультиколлинеарность или с утечкой целевого признака были убраны следующие столбцы:
#     - service_end_date
#     - uses_phone
#     - streaming_movies
#     - streaming_tv
#     - tech_premium_support
#     - antivirus
#     - cloud_file_storage
#     - online_security
#     - internet_connection_type
#     - service_duration
#     - has_dependents
#     - gender
# - Разделили датасет на features и target.
# - Разбили данные на обучающую и тестовую выборки в соотношении 3:1.
# - Подготовили данные для построения моделей (провели OHE кодирование и масштабирование для модели логистической регрессии, а также Ordinal кодирование для модели случайного леса).
#
# **3. Обучение и анализ работы моделей**
# - Построили, обучили и подобрали гиперпараметры для четырех моделей:
#     - Случайный лес.
#     - Логистическая регрессия.
#     - LGBM.
#     - CatBoost.
# - Оценка метрик моделей производилась по ROC AUC.
# - Лучшей моделью оказалась модель CatBoost со следующими гиперпараметрами:
#     - learning_rate': 0.1
#     - max_depth': 2
#     - n_estimators': 2300
#     - ROC AUC = 0.93
# - Была проведена проверка выбранной модели на тестовой выборке. Метрика ROC AUC на тестовой выбореке составила 0.943, что укладывается в целевой показатель проекта.
#
# **4. Оценка результатов**
#
# Построенная модель имеет высокую метрику Precision, а метрика Recall существенно ниже.
# На текущий момент у модели мало ложных срабатываний - если модель сообщила о том, что клиент собирается покинуть компанию, это действительно так с вероятностью 94%.
#
# Однако модель имеет невысокий показатель Recall говорит о том, что охват всех положительных целевых показателей невелик - модели удалось отыскать около 64% всех клиентов, собравшихся отказаться от услуг компании ТелеДом.
#
# Дальнейшее решение о доработке модели необходимо принимать на основании возможностей бизнеса:
# - Если позволяет финансовое состояние компании, стоит увеличить метрику Recall - в таком случае процент ложноположительных прогнозов увеличится, что повлечет дополнительные затраты на промокоды тем клиентам, которые не являются целевыми, но взамен большинство клиентов, планирующих отказаться от услуг, точно получат свой промокод.
# - Если компания ограничена в средствах, то можно оставить модель в её текущем состоянии, либо еще увеличить метрику Precision. В таком случае промокоды получат действительно только те клиенты, которые задумывались об уходе из компании.
#
# Анализ признаков:
# - Наибольший вклад в целевой показатель вносит признак длительности взаимодействия клиента и компании:
#     - Чем короче срок этого взаимодействия, тем чаще клиенты отказываются от услуг компании.
#     - Клиенты, имеющие средний срок и длительный работы с компанией наименее склонны к уходу.
# - Второй по значимости признак - общие затраты на услуги:
#     - Клиенты, имеющие общие затраты выше среднего показателя наиболее склонны к уходу. Верно и обратное.
# - Третий по значимости признак - тип оплаты (payment_type):
#     - Клиенты, тип оплаты которых раз в два года более склонны к уходу чем те, которые оплачивают раз в год. А последние в свою очередь более склонны к уходу чем клиенты, оплачивающие услуги раз в месяц. Возможно, здесь имеет влияние большой разовый платеж, который приходится делать клиентам с двугодичным периодом оплаты.
# - Четвертый признак - величина ежемесячных трат (monthly_costs). Здесь имеется полная аналогия с признаком total_costs - чем выше ежемесячные затраты, тем больше вероятность ухода клиента.
# - Последний более менее значимый признак - наличие супруга клиента:
#     - Клиенты, имеющие супругов, более склонны к уходу чем те, у которых их нет.
#
# **Рекомендации заказчику:**
#
# В качестве рекомендаций заказчику в данном случае можно посоветовать максимально направить усилия на улучшение пользовательского опыта в начале взаимодействия с компанией, так как именно новые пользователи - наиболее уязвимая часть аудитории.
#
# По возможности необходимо предоставлять новым пользователям скидки и промокоды на пользование различными услугами, так как стоимость услуг - второй наиболее важный фактор принятия решения об уходе из компании.
#
# В качестве третьей меры можно предложить убрать из тарифного плана опции оплаты услуг раз в два года в пользу более коротких сроков, например, раз в полгода, так как, судя по результатам моделирования, именно пользователи с таким типом подписки имеют наибольший шанс уйти из компании. Возможно, здесь имеет влияние большой разовый платеж, который приходится делать клиентам с двугодичным периодом оплаты.
